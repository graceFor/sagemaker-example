# %%
import numpy as np
import pandas as pd

# %%
# 데이터 불러오기
input_file = './train.csv'
df_titanic = pd.read_csv(input_file)

# %%
# df_titanic 행, 열 
df_titanic.shape
# Out:
# (891, 12)

# %%
# df_titanic 열 이름 확인하기
print (df_titanic.columns.values)
# Out:
# ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 결측값 확인
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 결측값 확인
df_titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# 인덱스 확인
print (df_titanic.index.name)
# Out:
# None

# %%
# 인덱스 생성 => PassengerId를 인덱스로 설정
df_titanic.set_index("PassengerId", inplace=True)

df_titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
# 인덱스 설정 후, 컬럼이 12->11개로 줄어듦
df_titanic.shape
# Out:
# (891, 11)

# %%
# 목적변수를 추출해 df_titanic_target 데이터 프레임 생성
df_titanic_target = df_titanic.loc[:,['Survived']]

# Survived 컬럼을 제외한 나머지 10개의 Feature를 df_titanic_features 데이터 프레임 생성
df_titanic_features = df_titanic.drop(['Survived'], axis=1)

# %%
# 목적변수값 분포 확인
df_titanic_target['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
# Survived 분포확인
# %matplotlib inline
import matplotlib.pyplot as plt
df_titanic_target.hist(figsize=(5,5))
# Out:
# array([[<AxesSubplot:title={'center':'Survived'}>]], dtype=object)

# %%
# 다른 컬럼들의 분포 확인
df_titanic_features.hist(figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'Pclass'}>,
#         <AxesSubplot:title={'center':'Age'}>],
#        [<AxesSubplot:title={'center':'SibSp'}>,
#         <AxesSubplot:title={'center':'Parch'}>],
#        [<AxesSubplot:title={'center':'Fare'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# Age 변수의 히스토그램

df_titanic_features.hist(column='Age', figsize=(5,5), bins=80)
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %%
# Embarked 속성 값들의 개수 확인하기(dropna=False를 설정하면 NaN도 포함해서 나타남)
df_titanic_features['Embarked'].value_counts(dropna=False)
# Out:
# S      644
# C      168
# Q       77
# NaN      2
# Name: Embarked, dtype: int64

# %%
# 'Embarked' 분포확인(NaN 포함)

vc = df_titanic_features['Embarked'].value_counts(dropna=False)
vc.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# 데이터의 통계적 특성 확인하기
df_titanic_features.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# 수치형 Feature들 boxplot으로 나타내기
df_titanic_features.boxplot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
# 연속형 변수들에 대해 상관계수 확인
df_titanic.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
# 목적 변수 Survived와의 상관관계 파악
corr_matrix = df_titanic.corr()
corr_matrix['Survived'].sort_values(ascending=False)
# Out:
# Survived    1.000000
# Fare        0.257307
# Parch       0.081629
# SibSp      -0.035322
# Age        -0.077221
# Pclass     -0.338481
# Name: Survived, dtype: float64

# %%
# scatter_matrix(산점도)를 통한 Feature들 간의 관계 파악
from pandas.plotting import scatter_matrix
scatter_matrix(df_titanic, figsize=(12,12))
# Out:
# array([[<AxesSubplot:xlabel='Survived', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Pclass', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Age', ylabel='Survived'>,
#         <AxesSubplot:xlabel='SibSp', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Parch', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Fare', ylabel='Survived'>],
#        [<AxesSubplot:xlabel='Survived', ylabel='Pclass'>,
#         <AxesSubplot:xlabel='Pclass', ylabel='Pclass'>,
#         <AxesSubplot:xlabel='Age', ylabel='Pclass'>,
#         <AxesSubplot:xlabel='SibSp', ylabel='Pclass'>,
#         <AxesSubplot:xlabel='Parch', ylabel='Pclass'>,
#         <AxesSubplot:xlabel='Fare', ylabel='Pclass'>],
#        [<AxesSubplot:xlabel='Survived', ylabel='Age'>,
#         <AxesSubplot:xlabel='Pclass', ylabel='Age'>,
#         <AxesSubplot:xlabel='Age', ylabel='Age'>,
#         <AxesSubplot:xlabel='SibSp', ylabel='Age'>,
#         <AxesSubplot:xlabel='Parch', ylabel='Age'>,
#         <AxesSubplot:xlabel='Fare', ylabel='Age'>],
#        [<AxesSubplot:xlabel='Survived', ylabel='SibSp'>,
#         <AxesSubplot:xlabel='Pclass', ylabel='SibSp'>,
#         <AxesSubplot:xlabel='Age', ylabel='SibSp'>,
#         <AxesSubplot:xlabel='SibSp', ylabel='SibSp'>,
#         <AxesSubplot:xlabel='Parch', ylabel='SibSp'>,
#         <AxesSubplot:xlabel='Fare', ylabel='SibSp'>],
#        [<AxesSubplot:xlabel='Survived', ylabel='Parch'>,
#         <AxesSubplot:xlabel='Pclass', ylabel='Parch'>,
#         <AxesSubplot:xlabel='Age', ylabel='Parch'>,
#         <AxesSubplot:xlabel='SibSp', ylabel='Parch'>,
#         <AxesSubplot:xlabel='Parch', ylabel='Parch'>,
#         <AxesSubplot:xlabel='Fare', ylabel='Parch'>],
#        [<AxesSubplot:xlabel='Survived', ylabel='Fare'>,
#         <AxesSubplot:xlabel='Pclass', ylabel='Fare'>,
#         <AxesSubplot:xlabel='Age', ylabel='Fare'>,
#         <AxesSubplot:xlabel='SibSp', ylabel='Fare'>,
#         <AxesSubplot:xlabel='Parch', ylabel='Fare'>,
#         <AxesSubplot:xlabel='Fare', ylabel='Fare'>]], dtype=object)

# %% [markdown]
# ## 결측값 다루기

# %%
# boxplot을 이용한 Age Feature 분포 파악
# %matplotlib inline
import matplotlib.pyplot as plt

df_titanic_features.boxplot(column='Age', figsize=(7,7))
# Out:
# <AxesSubplot:>

# %%
# 중간값으로 결측값 채우기
# 28.0이 중간값이므로 결측값에 대입
median_age = df_titanic_features['Age'].median()
print (median_age)

df_titanic_features["Age"].fillna(median_age, inplace=True)
# Out:
# 28.0

# %%
# Embarked의 결측값은 가장 많은 빈도 값으로 대체 => S

embarked_value_counts = df_titanic_features['Embarked'].value_counts(dropna=True)
most_common_value = embarked_value_counts.index[0]

print (most_common_value)

df_titanic_features["Embarked"].fillna(most_common_value, inplace=True)
# Out:
# S

# %%
# 'CabinIsKnown' Feature 생성 = Boolean의 속성을 가짐
# Cabin 값을 알면 True, 결측값이면 False
# does not have missing data
df_titanic_features['CabinIsKnown'] = ~df_titanic_features.Cabin.isnull()

# %%
# Cabin Featuer 삭제
df_titanic_features.drop(['Cabin'], axis=1, inplace=True)

# %%
# Feature 보기
df_titanic_features.columns.values
# Out:
# array(['Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare',
#        'Embarked', 'CabinIsKnown'], dtype=object)

# %%
# Feature에 존재하는 결측값 확인
df_titanic_features.isnull().sum()
# Out:
# Pclass          0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        0
# CabinIsKnown    0
# dtype: int64

# %% [markdown]
# ## 새로운 Featuer 생성하기

# %%
# SibSp와 Parch의 수를 더해 새로운 연속형 변수인 FamilySize Feature 생성
df_titanic_features['FamilySize'] = df_titanic_features.SibSp + df_titanic_features.Parch

# %%
# AgeCategory라는 새로운 범주형 Feature 생성
bins_age = [0,20,30,40,50,150]
labels_age = ['<20','20-30','30-40','40-50','>50']

df_titanic_features['AgeCategory'] = pd.cut(df_titanic_features.Age, 
                                            bins=bins_age, 
                                            labels=labels_age, 
                                            include_lowest=True)

# %%
# df_titanic_features 확인
df_titanic_features.head(10)
# Out:
#              Pclass                                               Name  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
# 6                 3                                   Moran, Mr. James
# 7                 1                            McCarthy, Mr. Timothy J
# 8                 3                     Palsson, Master. Gosta Leonard
# 9                 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                2                Nasser, Mrs. Nicholas (Adele Achem)
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Embarked  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500        S
# 2            female  38.0      1      0          PC 17599  71.2833        C
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250        S
# 4            female  35.0      1      0            113803  53.1000        S
# 5              male  35.0      0      0            373450   8.0500        S
# 6              male  28.0      0      0            330877   8.4583        Q
# 7              male  54.0      0      0             17463  51.8625        S
# 8              male   2.0      3      1            349909  21.0750        S
# 9            female  27.0      0      2            347742  11.1333        S
# 10           female  14.0      1      0            237736  30.0708        C
#
#              CabinIsKnown  FamilySize AgeCategory
# PassengerId
# 1                   False           1       20-30
# 2                    True           1       30-40
# 3                   False           0       20-30
# 4                    True           1       30-40
# 5                   False           0       30-40
# 6                   False           0       20-30
# 7                    True           0         >50
# 8                   False           4         <20
# 9                   False           2       20-30
# 10                  False           1         <20

# %%
# FareCategory라는 새로운 범주형 Feature 생성
df_titanic_features['FareCategory'] = pd.qcut(df_titanic_features.Fare, 
                                            q=4, 
                                            labels=['Q1', 'Q2', 'Q3', 'Q4'])

# %%
# df_titanic_features 확인
df_titanic_features.head(10)
# Out:
#              Pclass                                               Name  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
# 6                 3                                   Moran, Mr. James
# 7                 1                            McCarthy, Mr. Timothy J
# 8                 3                     Palsson, Master. Gosta Leonard
# 9                 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                2                Nasser, Mrs. Nicholas (Adele Achem)
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Embarked  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500        S
# 2            female  38.0      1      0          PC 17599  71.2833        C
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250        S
# 4            female  35.0      1      0            113803  53.1000        S
# 5              male  35.0      0      0            373450   8.0500        S
# 6              male  28.0      0      0            330877   8.4583        Q
# 7              male  54.0      0      0             17463  51.8625        S
# 8              male   2.0      3      1            349909  21.0750        S
# 9            female  27.0      0      2            347742  11.1333        S
# 10           female  14.0      1      0            237736  30.0708        C
#
#              CabinIsKnown  FamilySize AgeCategory FareCategory
# PassengerId
# 1                   False           1       20-30           Q1
# 2                    True           1       30-40           Q4
# 3                   False           0       20-30           Q2
# 4                    True           1       30-40           Q4
# 5                   False           0       30-40           Q2
# 6                   False           0       20-30           Q2
# 7                    True           0         >50           Q4
# 8                   False           4         <20           Q3
# 9                   False           2       20-30           Q2
# 10                  False           1         <20           Q3

# %% [markdown]
# ## 수치형 Feature 변환하기
# ### 머신러닝 알고리즘에서는 범주형 데이터를 처리할 수 없어서 변환이 필요

# %%
# MinMaxScaler를 사용해 NormalizedAge라는 새로운 피처 생성
from sklearn import preprocessing

minmax_scaler = preprocessing.MinMaxScaler()
ndNormalizedAge = minmax_scaler.fit_transform(df_titanic_features[['Age']].values)
df_titanic_features['NormalizedAge']  = pd.DataFrame(ndNormalizedAge)

# StandardScaler 사용해 StandardizedAge라는 새로운 피처 생성
standard_scaler = preprocessing.StandardScaler()
ndStandardizedAge = standard_scaler.fit_transform(df_titanic_features[['Age']].values)
df_titanic_features['StandardizedAge']  = pd.DataFrame(ndStandardizedAge)

# histogram of Age, NormalizedAge, StandardizedAge
df_titanic_features[['Age', 'NormalizedAge', 'StandardizedAge']].hist(figsize=(10,10), bins=5)
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'NormalizedAge'}>],
#        [<AxesSubplot:title={'center':'StandardizedAge'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# one-hot encoding을 통해 수치형 데이터로 변환
# into binary numeric attributes
df_titanic_features = pd.get_dummies(df_titanic_features, columns=['Sex','Embarked','CabinIsKnown','AgeCategory','FareCategory'])

# display the columns of the dataframe.
print (df_titanic_features.columns.values)
# Out:
# ['Pclass' 'Name' 'Age' 'SibSp' 'Parch' 'Ticket' 'Fare' 'FamilySize'
#  'NormalizedAge' 'StandardizedAge' 'Sex_female' 'Sex_male' 'Embarked_C'
#  'Embarked_Q' 'Embarked_S' 'CabinIsKnown_False' 'CabinIsKnown_True'
#  'AgeCategory_<20' 'AgeCategory_20-30' 'AgeCategory_30-40'
#  'AgeCategory_40-50' 'AgeCategory_>50' 'FareCategory_Q1' 'FareCategory_Q2'
#  'FareCategory_Q3' 'FareCategory_Q4']

# %%
df_titanic_features
# Out:
#              Pclass                                               Name   Age  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris  22.0
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3                 3                             Heikkinen, Miss. Laina  26.0
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5                 3                           Allen, Mr. William Henry  35.0
# ...             ...                                                ...   ...
# 887               2                              Montvila, Rev. Juozas  27.0
# 888               1                       Graham, Miss. Margaret Edith  19.0
# 889               3           Johnston, Miss. Catherine Helen "Carrie"  28.0
# 890               1                              Behr, Mr. Karl Howell  26.0
# 891               3                                Dooley, Mr. Patrick  32.0
#
#              SibSp  Parch            Ticket     Fare  FamilySize  \
# PassengerId
# 1                1      0         A/5 21171   7.2500           1
# 2                1      0          PC 17599  71.2833           1
# 3                0      0  STON/O2. 3101282   7.9250           0
# 4                1      0            113803  53.1000           1
# 5                0      0            373450   8.0500           0
# ...            ...    ...               ...      ...         ...
# 887              0      0            211536  13.0000           0
# 888              0      0            112053  30.0000           0
# 889              1      2        W./C. 6607  23.4500           3
# 890              0      0            111369  30.0000           0
# 891              0      0            370376   7.7500           0
#
#              NormalizedAge  StandardizedAge  ...  CabinIsKnown_True  \
# PassengerId                                  ...
# 1                 0.472229         0.663861  ...                  0
# 2                 0.321438        -0.258337  ...                  1
# 3                 0.434531         0.433312  ...                  0
# 4                 0.434531         0.433312  ...                  1
# 5                 0.346569        -0.104637  ...                  0
# ...                    ...              ...  ...                ...
# 887               0.233476        -0.796286  ...                  0
# 888               0.346569        -0.104637  ...                  1
# 889               0.321438        -0.258337  ...                  0
# 890               0.396833         0.202762  ...                  1
# 891                    NaN              NaN  ...                  0
#
#              AgeCategory_<20  AgeCategory_20-30  AgeCategory_30-40  \
# PassengerId
# 1                          0                  1                  0
# 2                          0                  0                  1
# 3                          0                  1                  0
# 4                          0                  0                  1
# 5                          0                  0                  1
# ...                      ...                ...                ...
# 887                        0                  1                  0
# 888                        1                  0                  0
# 889                        0                  1                  0
# 890                        0                  1                  0
# 891                        0                  0                  1
#
#              AgeCategory_40-50  AgeCategory_>50  FareCategory_Q1  \
# PassengerId
# 1                            0                0                1
# 2                            0                0                0
# 3                            0                0                0
# 4                            0                0                0
# 5                            0                0                0
# ...                        ...              ...              ...
# 887                          0                0                0
# 888                          0                0                0
# 889                          0                0                0
# 890                          0                0                0
# 891                          0                0                1
#
#              FareCategory_Q2  FareCategory_Q3  FareCategory_Q4
# PassengerId
# 1                          0                0                0
# 2                          0                0                1
# 3                          1                0                0
# 4                          0                0                1
# 5                          1                0                0
# ...                      ...              ...              ...
# 887                        1                0                0
# 888                        0                1                0
# 889                        0                1                0
# 890                        0                1                0
# 891                        0                0                0
#
# [891 rows x 26 columns]

# %%
df_titanic_features[['Sex_male', 'Sex_female']].head()
# Out:
#              Sex_male  Sex_female
# PassengerId
# 1                   1           0
# 2                   0           1
# 3                   0           1
# 4                   0           1
# 5                   1           0

# %%
# Sex_male과 Sex_femaile은 강한 음의 상관관계 가짐
# 둘 중 하나 삭제해도 됨
# Sex_male이 0이면 Sex_femaile은 1이므로
# CabinIsKnown_False와 CabinIsKnown_True도 동일

corr_matrix = df_titanic_features[['Sex_male', 'Sex_female']].corr()
print(corr_matrix)
# Out:
#             Sex_male  Sex_female
# Sex_male         1.0        -1.0
# Sex_female      -1.0         1.0

# %%
# Name, Ticket은 비수치형 컬럼이므로 삭제
# Sex_female, CabinIsKnown_False도 Sex_male, CabinIsKnown_True만 있어도 되므로 삭제
# 이렇게 삭제해주므로 linear 또는 logistic regression에 사용할 수 있음
df_titanic_features_numeric = df_titanic_features.drop(['Name', 'Ticket', 'Sex_female', 'CabinIsKnown_False'], axis=1)

# %%
#df_titanic_features_numeric와 df_titanic['Survived'] 하나의 데이터 프레임으로 합치기
df_temporary = pd.concat([df_titanic_features_numeric, df_titanic['Survived']], axis=1)
df_temporary.head()
# Out:
#              Pclass   Age  SibSp  Parch     Fare  FamilySize  NormalizedAge  \
# PassengerId
# 1                 3  22.0      1      0   7.2500           1       0.472229
# 2                 1  38.0      1      0  71.2833           1       0.321438
# 3                 3  26.0      0      0   7.9250           0       0.434531
# 4                 1  35.0      1      0  53.1000           1       0.434531
# 5                 3  35.0      0      0   8.0500           0       0.346569
#
#              StandardizedAge  Sex_male  Embarked_C  ...  AgeCategory_<20  \
# PassengerId                                         ...
# 1                   0.663861         1           0  ...                0
# 2                  -0.258337         0           1  ...                0
# 3                   0.433312         0           0  ...                0
# 4                   0.433312         0           0  ...                0
# 5                  -0.104637         1           0  ...                0
#
#              AgeCategory_20-30  AgeCategory_30-40  AgeCategory_40-50  \
# PassengerId
# 1                            1                  0                  0
# 2                            0                  1                  0
# 3                            1                  0                  0
# 4                            0                  1                  0
# 5                            0                  1                  0
#
#              AgeCategory_>50  FareCategory_Q1  FareCategory_Q2  \
# PassengerId
# 1                          0                1                0
# 2                          0                0                0
# 3                          0                0                1
# 4                          0                0                0
# 5                          0                0                1
#
#              FareCategory_Q3  FareCategory_Q4  Survived
# PassengerId
# 1                          0                0         0
# 2                          0                1         1
# 3                          0                0         1
# 4                          0                1         1
# 5                          0                0         0
#
# [5 rows x 23 columns]

# %%
# 어떤 피처들이 목적변수 Survived와 어떤 상관관계를 보인지는 파악하기
corr_matrix = df_temporary.corr()
corr_matrix['Survived'].sort_values(ascending=False)
# Out:
# Survived             1.000000
# CabinIsKnown_True    0.316912
# Fare                 0.257307
# FareCategory_Q4      0.233638
# Embarked_C           0.168240
# FareCategory_Q3      0.084239
# Parch                0.081629
# AgeCategory_<20      0.076565
# AgeCategory_30-40    0.057867
# FamilySize           0.016639
# Embarked_Q           0.003650
# AgeCategory_40-50   -0.000079
# NormalizedAge       -0.001654
# StandardizedAge     -0.001654
# AgeCategory_>50     -0.022932
# SibSp               -0.035322
# Age                 -0.064910
# AgeCategory_20-30   -0.093689
# FareCategory_Q2     -0.095648
# Embarked_S          -0.149683
# FareCategory_Q1     -0.221610
# Pclass              -0.338481
# Sex_male            -0.543351
# Name: Survived, dtype: float64

# %%
print('Done')
# Out:
# Done
